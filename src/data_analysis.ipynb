# %%
import pandas as pd

# %%
extra = pd.read_excel('../Base_de_donnees_suisse_des_valeurs_nutritives.xlsx', header=2)
extra
# Out:
#          ID  ID V 4.0  ID SwissFIR  \
# 0       621    3599.0    1001168.0
# 1     14097       NaN          NaN
# 2       379    3629.0    1000842.0
# 3      1051    3766.0          NaN
# 4       469    4047.0    1000952.0
# ...     ...       ...          ...
# 1087    590    3618.0    1001127.0
# 1088   1192    4710.0          NaN
# 1089     52    4469.0     821027.0
# 1090    587    4141.0    1001123.0
# 1091    759    4583.0    1001402.0
#
#                                                     Nom Synonymes  \
# 0               Abricot, au sirop, en conserve, égoutté       NaN
# 1        Abricot, avec édulcorant, en conserve, égoutté       NaN
# 2                                          Abricot, cru       NaN
# 3     Abricot, cuit,  égoutté (sans adjonction de su...       NaN
# 4                                          Abricot, sec       NaN
# ...                                                 ...       ...
# 1087               Yogourt maigre avec arômes, édulcoré    Yaourt
# ...

# %%
extra.Catégorie.unique()
# Out:
# array(['Fruits/Fruits cuits (conserves comprises)', 'Fruits/Fruits frais',
#        'Fruits/Fruits secs', 'Divers/Gélifiants et liants',
#        'Viande et abats/Agneau, mouton', 'Légumes/Légumes frais',
#        'Légumes/Légumes secs', 'Noix, graines et produits oléagineux',
#        'Snacks salés/Noix et graines salées',
#        'Produits céréaliers, légumineuses et pommes de terre/Autres produits céréaliers',
#        'Sucreries/Biscuits',
#        'Produits céréaliers, légumineuses et pommes de terre/Farines et amidon;Divers/Gélifiants et liants',
#        'Poisson/Poissons de mer',
#        'Lait et produits laitiers/Fromage à pâte dure',
#        'Légumes/Légumes cuits (conserves comprises)',
#        'Légumes/Légumes frais;Noix, graines et produits oléagineux',
#        'Pains, flocons et céréales pour le petit-déjeuner/Flocons, son et germes',
#        'Lait et produits laitiers/Boissons lactées et yogourts à boire',
# ...
