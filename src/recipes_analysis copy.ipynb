# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from constant import *
from helpers import *

# %% [markdown]
# ### 1. Data Loading

# %%
DATA_DIR = '../res/recipes/'

# %%
# Collect all the recipes for all regions
recipes_lst = []
for filename in os.listdir(DATA_DIR):
  if filename.endswith('.txt'):
    recipes_lst += read_region_file(DATA_DIR+filename)

# Create the dataframe with all the recipes
recipes_df = pd.DataFrame(
  recipes_lst, 
  columns= ['subregion', 'recipe_name', 'ingredients_inferred', 'nb_persons', 'ingredients', 'recipe_body']
)

# %%
recipes_df.head()
# Out:
#   subregion                           recipe_name ingredients_inferred  \
# 0    Alsace                          LE KUGELHOPF                 with
# 1    Alsace                      LE SCHWOWCBREDEL                 with
# 2    Alsace  PARFAIT DE FOIE GRAS STRASBOURGEOISE                 with
# 3    Alsace       TRUITES DE LA FECHT COLMARIENNE                 with
# 4    Alsace                        LES SCHANKELAS                 with
#
#   nb_persons                                        ingredients  \
# 0          6  0.5 litre de lait\n500 g farine\n250 g beurre\...
# 1          6  500 g farine\n500 g sucre\n500 g amandes\n500 ...
# 2          -  1 kg foie gras oiseau\n1 truffe\n1 dl gelée\n1...
# 3          4  4 truites\n8 écrevisses\n4 œufs\n50 g oignons\...
# 4          -  375 g sucre\n250 g amandes\n200 g beurre\n250 ...
#
#                                          recipe_body
# 0  Pour 6 personnes : Mettez dans une terrine 1/2...
# 1  Pour 6 personnes: Mélanger farine et beurre. R...
# 2  1 kg de foie gras d’Alsace 1er qualité, dénerv...
# 3  Pour 4 personnes: Prenez 4 belles truites du t...
# 4  Ecraser le beurre avec la farine et bien mêler...

# %%
len(recipes_df)
# Out:
# 352

# %%
recipes_df.subregion.nunique()
# Out:
# 30

# %% [markdown]
# ### 2. Data Processing

# %%
contents = collect_all_ingredient_contents(recipes_df)
print(len(contents))
# Out:
# 632

# %%
contents
# Out:
# {'Béchamel',
#  'Merluza',
#  'Rouille',
#  'SAUCE A LA RAVIGOTE',
#  'SAUCE BERCY',
#  'SAUCE BORDELAISE',
#  'SAUCE PERIGUEUX',
#  'SAUCE PIQUANTE',
#  'SAUCE PRIEURE',
#  'SAUCE QUERCYNOISE',
#  'SAUCE TARTARE',
#  'abatis oie ou canard',
#  'abricots',
#  'ail',
#  'alcool Vermouth blanc',
#  'alose',
#  'alouette oiseau',
#  'alouettes oiseau',
#  'amandes',
#  'amandes pilées',
#  'anchois',
#  'anguilles',
#  'angélique',
#  'angélique en poudre',
#  'anis en grains',
#  'aromate',
#  'aromates',
#  'artichaut',
#  'aubergines',
#  'bacon porc',
#  'baies de genièvre',
#  'baies genièvre',
#  'bananes',
#  'barbue ou turbot',
#  'barde de lard porc',
#  'barde de lard salé porc',
#  'bardes de lard porc',
#  'bardes lard porc',
#  'bas morceaux de veau',
#  'basilic',
#  'baudruche de bœuf',
#  'bette',
#  'betteraves',
#  'beurre',
#  "beurre d'anchois",
#  "beurre d'écrevisses",
#  'beurre fin',
#  'beurre tiède',
#  'bicarbonate',
#  'bière',
#  "blanc d'œuf",
#  'blanc de poireau',
#  'blanc de poireaux',
#  'blanc de poule',
#  'blanc de volaille',
#  'blancs de poireaux',
#  'bouillon',
#  "bouillon d'os",
#  'bouillon de bœuf et veau',
#  'bouillon de pot au feu',
#  'bouillon de poule',
#  'bouillon gras',
#  'bouquet de persil',
#  'bouquet de sarriette',
#  'bouquet garni',
#  'bouquets garnis',
#  'boyau de porc',
#  'brochets',
#  'brême',
#  'béchamel',
#  'bœuf',
#  'bœuf ou veau',
#  'caille',
#  'cailles',
#  'canapés',
#  'canard',
#  'caneton',
#  'canetons',
#  'cannelle',
#  'cannelle en poudre',
#  'cardon',
#  'carotte',
#  'carottes',
#  'carpe',
#  'carpes',
#  'carré de mouton',
#  'cerfeuil',
#  'cerises',
#  'cerises confites',
#  'cervelas truffé',
#  'chair de brochet',
#  'chair à brochet',
#  'chair à saucisse viande',
#  'champignon',
#  'champignons',
#  'champignons Hygrophores',
#  'champignons de Paris',
#  'champignons de couche',
#  'champignons pied-de-mouton',
#  'chapelure',
#  'chapelure de pain',
#  'chipirones',
#  'chocolat',
#  'chorizo',
#  'chou',
#  'chou blanc',
#  'chou pommé',
#  'choucroute',
#  'ciboule',
#  'ciboulette',
#  'ciboulettes',
#  'cidre',
#  'cidre ou vin rouge',
#  'citron',
#  'citron râpé',
#  'citrons',
#  'cive',
#  'clou de girofle',
#  'clou girofle',
#  'clous de girofle',
#  'clous girofle',
#  'cochon',
#  'coing',
#  'colin',
#  'concentré de tomate',
#  "confit d'oie",
#  'confiture',
#  'congre',
#  'consommé',
#  'coq',
#  'coquilles',
#  'coriandre',
#  'cornichon',
#  'cornichons',
#  'couenne de lard porc',
#  'couenne de porc',
#  'couennes de lard porc',
#  'couennes porc',
#  'coulis de tomates',
#  'courgettes',
#  'court-bouillon',
#  'cous de mouton',
#  'cresson',
#  'crevettes',
#  'crevettes roses',
#  'croûton de pain',
#  'croûtons',
#  'croûtons frits',
#  'crème',
#  'crème ',
#  'crème Chantilly',
#  'crème double',
#  'crème fraîche',
#  'crème patissière ou confitures cerises',
#  'crème épaisse',
#  'curry',
#  'câpre',
#  'câpres',
#  'cèpes',
#  'cédrat confit',
#  'céleri',
#  'côte de bœuf',
#  'côtelette de chevreuil',
#  'côtelettes',
#  'côtes de porc',
#  'cœur céleri',
#  'demi-glace viande',
#  'duxelle',
#  'eau',
#  "eau fleur d'oranger",
#  'eau-de-vie',
#  'eau-de-vie Armagnac',
#  'eau-de-vie Calvados',
#  'eau-de-vie Cognac',
#  'eau-de-vie Cognac ou eau-de-vie Armagnac',
#  'eau-de-vie Genièvre',
#  'eau-de-vie Kirsch',
#  'eau-de-vie Mirabelle',
#  'eau-de-vie Rhum',
#  'eau-de-vie Rhum ou eau-de-vie Cognac',
#  'eau-de-vie marc Touraine ou eau-de-vie Cognac',
#  'entrecôte bœuf',
#  'escalope de veau',
#  'escargots',
#  'essence de citron',
#  'estragon',
#  'faisan',
#  'farce',
#  'farce de porc',
#  'farine',
#  'farine blé',
#  'farine de blé',
#  'farine de blé noir',
#  'farine de châtaigne',
#  'farine de maïs',
#  'farine de sarrasin',
#  'farine gruau',
#  'fenouil',
#  'feuille de laurier',
#  'feuille de vigne',
#  'feuille laurier',
#  "feuilles d'oseille",
#  'feuilles de châtaignier',
#  'feuilles estragon',
#  'filet anchois',
#  "filet d'anchois",
#  'filet de bœuf',
#  'filet de lapin',
#  'filet de lard porc',
#  'filet de porc',
#  'filet porc',
#  'filets anchois',
#  'filets de morue',
#  'filets de soles',
#  'filets harengs',
#  'filets morue',
#  'fine ',
#  'fine Bourgogne',
#  'fine Champagne',
#  'fines herbes',
#  "fleur d'oranger",
#  "fleurs d'oranger",
#  'foie de canard',
#  'foie de porc',
#  'foie de volaille',
#  'foie gras oiseau',
#  'foie gras truffé oiseau',
#  'foie lapin ou foie poulet',
#  'foie viande',
#  'foie volaille',
#  'foies de volaille',
#  'foies poulardes de Bresse',
#  'fond brun',
#  'fond de veau',
#  'fond de veau lié',
#  'fraises des bois',
#  'framboises',
#  'fromage Cantal',
#  'fromage Méton',
#  'fromage brocciu',
#  'fromage de Gruyère',
#  'fromage râpé',
#  'fumet de poissons',
#  'fécule',
#  'févette',
#  'gelée',
#  'gelée de groseille',
#  'gelée de groseilles',
#  'genièvre',
#  'gibier',
#  "gigot d'agneau",
#  'girofle',
#  'gite de bœuf',
#  'glace de viande',
#  'glace de viande ou jus de rôti de veau',
#  'goujon',
#  "gousse d'ail",
#  'grain de genièvre',
#  "grains d'anis",
#  'grains de poivre',
#  'grains de raisin',
#  'grains genièvre',
#  'grains raisin frais',
#  "graisse d'oie",
#  "graisse de confit d'oie",
#  'graisse de porc',
#  'graisse normande bœuf',
#  'gras de porc',
#  'gras-double bœuf',
#  'grenouilles',
#  'grive de vignes oiseau',
#  'grives oiseau',
#  'gros chou',
#  'gros grondin',
#  'gros oignon',
#  'gros oignons',
#  'gros pain',
#  'gros poivre',
#  'gros sel',
#  'grosse raie',
#  'grosses pommes de terre',
#  'gruyère',
#  'gruyère râpé',
#  'gélatine',
#  "hachis d'herbes",
#  'hachis de levraut',
#  'harengs marinés',
#  'haricot',
#  'haricots',
#  'haricots blancs',
#  'haricots mougettes',
#  'haricots secs',
#  'haricots verts',
#  'haricots verts OU 125 g flageolets',
#  'homard',
#  'huile',
#  "huile d'olive",
#  'huile de noix',
#  'huile olive',
#  'huîtres',
#  'jambon Bayonne porc',
#  'jambon de Bayonne porc',
#  'jambon des Landes porc',
#  'jambon fumé porc',
#  'jambon haché porc',
#  'jambon maigre porc',
#  'jambon porc',
#  'jarret de porc',
#  'jarret veau',
#  'jarret veau ou épaule veau',
#  'jarrets de veau',
#  "jaune d'œuf",
#  "jaunes d'œufs",
#  'jaunes œufs',
#  'jeune caneton',
#  'jeune poule',
#  'jus de citron',
#  'jus de rôti de veau',
#  'jus de rôti viande',
#  'jus de veau',
#  'jus de viande',
#  'lait',
#  'lait de beurre',
#  'lait frais',
#  'laitance carpes',
#  'laitue',
#  'laitues',
#  'lamproie',
#  'langouste',
#  'langoustines',
#  'langoustines crues',
#  'lapin',
#  'lapin de garenne',
#  'lard de poitrine porc',
#  'lard frais porc',
#  'lard fumé porc',
#  'lard gras porc',
#  'lard maigre porc',
#  'lard poitrine fumé porc',
#  'lard porc',
#  'lardons porc',
#  'lards porc',
#  'laurier',
#  'levain',
#  'levain salé',
#  'levreau',
#  'levure',
#  'levure de boulanger',
#  'liqueur Cherry',
#  'liqueur Izarra',
#  'lièvre',
#  'lotte',
#  'loup',
#  'légumes',
#  'maigre de porc',
#  'maquereaux',
#  'marron',
#  'marrons',
#  'mayonnaise',
#  'menthe',
#  'merlans',
#  'merle oiseau',
#  'miche de pain',
#  'mie de pain',
#  'mie de pain brioché',
#  'mirepoix',
#  'moelle de bœuf',
#  'morilles',
#  'morue sèche',
#  'moule',
#  'moules',
#  'moules marinière',
#  'moutarde',
#  'mouton',
#  'muscade',
#  'navet',
#  'navets',
#  'noisettes',
#  'noix',
#  'noix de muscade',
#  'noix de veau',
#  'oie',
#  'oignon',
#  'oignon moyen',
#  'oignons',
#  'olive noire',
#  'olives',
#  'olives dénoyautées',
#  'olives noires',
#  'olives vertes',
#  'omble',
#  'orange',
#  'oronges des Césars oiseau',
#  'oronges oiseau',
#  'ortolans oiseau',
#  'os salé viande',
#  'oseille',
#  'pain',
#  'pain bis',
#  'pain de seigle',
#  'pain rassis',
#  'palette porc',
#  'palombes',
#  'palourdes',
#  'panais',
#  'panne de porc',
#  'panne porc',
#  'paprika',
#  'paprika doux',
#  'parmesan',
#  'parmesan râpé',
#  'perche',
#  'perdrix oiseau',
#  'persil',
#  'persil haché',
#  'petit chou',
#  'petit lait',
#  'petit oignon',
#  'petit pois',
#  'petit poisson',
#  'petites seiches',
#  'petites écrevisses',
#  'petits champignons',
#  'petits oignons',
#  'petits pains blancs',
#  'petits pois',
#  'petits pois écossés',
#  'petits poulets',
#  'pied de bœuf',
#  'pied de veau',
#  'pied mouton',
#  'pieds cochon',
#  'pieds céleri',
#  'pieds de porc truffés',
#  'pieds de veau',
#  'pigeons oiseau',
#  'piment',
#  'piment de Cayenne',
#  'piment doux',
#  'piment rouge',
#  'piments espagnols',
#  'piments morones',
#  'piments verts',
#  'pincée de safran',
#  'pissenlit',
#  'plates côtes bœuf',
#  'pointe ail',
#  'pointe de Cayenne',
#  'pointe de piment de Cayenne',
#  "pointes d'asperges",
#  'poireau',
#  'poireaux',
#  'pois',
#  'pois cassés',
#  'pois frais',
#  'pois nouveaux',
#  'poisson',
#  'poisson cuit',
#  'poissons',
#  'poitrine de porc',
#  'poitrine porc',
#  'poitrine salée porc',
#  'poitrine veau',
#  'poivre',
#  'poivre en grains',
#  'poivre rouge',
#  'poivre rouge doux',
#  'poivrons',
#  'pomme',
#  'pomme de terre',
#  'pomme reinette',
#  'pommes',
#  'pommes de terre',
#  'pommes reinette',
#  'pommes reinettes du Canada',
#  'porc',
#  'porc ou lapin ou poulet',
#  'potirons',
#  'poudre champignons',
#  'poularde',
#  'poule',
#  'poulet',
#  'poulet de Bresse',
#  'poulpes',
#  'praline',
#  'pruneau',
#  'pruneaux',
#  "purée d'anchois",
#  'purée de tomate',
#  'pâte',
#  'pâte brisée',
#  'pâte feuilletée',
#  'pâte à brioche',
#  'pâte à choux',
#  'pâte à pain',
#  'quelques amandes',
#  "queues d'écrevisses",
#  'rable de lièvre',
#  'raisin',
#  'raisin muscat',
#  'raisins Malaga',
#  'rascasse',
#  'raves',
#  'rillettes porc',
#  'rillons sans os porc',
#  'riz',
#  'riz Caroline',
#  'romarin',
#  'rouge de carottes',
#  'rouget',
#  'rougets',
#  'rumsteack bœuf',
#  'râpure de citron',
#  'safran',
#  'saindoux porc',
#  'salade',
#  'salsifis',
#  'salsifis noirs',
#  'sang de porc',
#  'sang de poulet',
#  'sang de veau ou sang de porc',
#  'sardines',
#  'sarriette',
#  'sauce blanche',
#  'sauce béchamel',
#  'sauce mornay',
#  'sauce normande',
#  'sauce poivrade',
#  'sauce tomate',
#  'saucisse de campagne viande',
#  'saucisses de campagne viande',
#  'saucisses porc',
#  'saucisson porc',
#  'saucisson viande',
#  'sauge',
#  'saumon',
#  'sel',
#  'serpolet',
#  'sole',
#  'soles',
#  'sucre',
#  'sucre cristallisé',
#  'sucre en poudre',
#  'sucre fin',
#  'sucre glace',
#  'sucre ou cassonade',
#  'sucre poudre',
#  'thon',
#  'thon nouveau',
#  'thym',
#  'toast',
#  'tomate',
#  'tomate concentrée',
#  'tomate fraiche OU 1 cuil. tomate concentrée',
#  'tomates',
#  'tomates coupées',
#  'tomates fraîches',
#  'tomates fraîches OU 6 cuil. tomate concentrée',
#  'tourterelles oiseau',
#  'tranches de jambon porc ou boudin noir porc',
#  'tranches de pain',
#  'tripes de veau',
#  'truffe',
#  'truffe noire',
#  'truffes',
#  'truite',
#  'truites',
#  'tête de veau',
#  'tête merlu',
#  "têtes d'ail",
#  'vanille',
#  'veau',
#  'velouté de volaille',
#  'viande de porc',
#  'viande de veau',
#  'vin',
#  'vin Bourgogne',
#  'vin Chablis',
#  'vin Chambertin',
#  'vin Champagne',
#  'vin Châteauneuf-du-Pape',
#  'vin Frontignan',
#  'vin Jurançon',
#  'vin Madère',
#  'vin Monbazillac',
#  'vin Pouilly',
#  'vin Vouvray',
#  'vin blanc',
#  'vin blanc Monbozillac',
#  'vin blanc ou cidre',
#  'vin blanc sec',
#  'vin blanc sec corsé',
#  "vin d'Arbois",
#  'vin de Chablis',
#  'vin de Vouvray',
#  'vin gris de Bruley',
#  'vin jaune',
#  'vin muscat',
#  'vin porto',
#  'vin rosé',
#  'vin rouge',
#  'vinaigre',
#  'vinaigre blanc',
#  'vinaigre de cidre',
#  'vinaigre de vin',
#  'vinaigrette',
#  'volaille ou viande froide',
#  'zeste citron',
#  "zeste d'orange",
#  'zeste de citron',
#  'zeste orange',
#  'échalote',
#  'échalote grise',
#  'échalotes',
#  'échalotes hachées',
#  'échaudé',
#  'échine porc',
#  "écorce d'orange ou écorce de citron",
#  'écorce orange confite',
#  'écrevisse',
#  'écrevisses',
#  'épaule de mouton',
#  'épaule de porc',
#  'épaule et palette porc',
#  'épices',
#  'épinard',
#  'épinards',
#  'œuf',
#  'œufs',
#  'œufs battus',
#  'œufs entiers',
#  'œufs mollets'}

# %%
contents_multiset = ingredients_frequency(recipes_df)
{k: v for k, v in sorted(contents_multiset.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'beurre': 180,
#  'sel': 167,
#  'poivre': 146,
#  'œufs': 101,
#  'oignons': 95,
#  'farine': 89,
#  'persil': 82,
#  'ail': 76,
#  'vin blanc': 69,
#  'bouquet garni': 46,
#  'échalotes': 41,
#  'carottes': 37,
#  'champignons': 37,
#  'laurier': 35,
#  'lait': 33,
#  "huile d'olive": 32,
#  'citron': 31,
#  'bouillon': 31,
#  'sucre': 30,
#  'thym': 28,
#  'pommes de terre': 27,
#  'vinaigre': 26,
#  'estragon': 26,
#  'huile': 25,
#  'échalote': 24,
#  'tomates': 24,
#  'lard porc': 22,
#  'muscade': 19,
#  'vin rouge': 18,
#  'truffe': 17,
#  'crème fraîche': 17,
#  'cerfeuil': 17,
#  'jambon porc': 16,
#  'épices': 15,
#  'moutarde': 14,
#  'mie de pain': 14,
#  'crème': 14,
#  'poulet': 13,
#  'petits oignons': 13,
#  'foie gras oiseau': 12,
#  'crème double': 12,
#  'céleri': 11,
#  'gruyère': 11,
#  'poireaux': 11,
#  'eau-de-vie': 11,
#  'sucre en poudre': 11,
#  'écrevisses': 9,
#  'pomme de terre': 9,
#  'truffes': 9,
#  'lardons porc': 9,
#  'chapelure': 8,
#  'pain': 8,
#  'fines herbes': 8,
#  'clou de girofle': 8,
#  'gros oignons': 8,
#  'piment rouge': 8,
#  'clous de girofle': 8,
#  'veau': 8,
#  'vinaigre de vin': 8,
#  'eau-de-vie Armagnac': 8,
#  'moules': 7,
#  'poissons': 7,
#  'riz': 7,
#  'eau-de-vie Cognac': 7,
#  'poivre en grains': 7,
#  'truites': 6,
#  "graisse d'oie": 6,
#  'bœuf': 6,
#  'ciboulette': 6,
#  'safran': 6,
#  'pied de veau': 6,
#  'cornichons': 6,
#  'sarriette': 6,
#  'paprika': 6,
#  'eau-de-vie Kirsch': 5,
#  'sauce tomate': 5,
#  'lard de poitrine porc': 5,
#  'porc': 5,
#  'cèpes': 5,
#  'fenouil': 5,
#  'câpres': 5,
#  "jaunes d'œufs": 5,
#  'aubergines': 5,
#  'gruyère râpé': 5,
#  'olives noires': 5,
#  'huile olive': 5,
#  'morilles': 5,
#  'eau-de-vie Calvados': 5,
#  'croûtons frits': 5,
#  'filet de porc': 5,
#  'lapin': 5,
#  'béchamel': 5,
#  'pâte feuilletée': 5,
#  'navets': 5,
#  'amandes': 4,
#  'vanille': 4,
#  "fleur d'oranger": 4,
#  'eau': 4,
#  'lièvre': 4,
#  'barde de lard porc': 4,
#  'cailles': 4,
#  'lard gras porc': 4,
#  'anchois': 4,
#  'laitue': 4,
#  'saindoux porc': 4,
#  'consommé': 4,
#  'alose': 4,
#  'canard': 4,
#  'chou': 4,
#  'vin Madère': 4,
#  'croûtons': 4,
#  'vin blanc sec': 4,
#  'haricots': 4,
#  'jus de citron': 4,
#  'légumes': 3,
#  'pommes': 3,
#  'oseille': 3,
#  'crème Chantilly': 3,
#  'lotte': 3,
#  'crevettes': 3,
#  'ciboule': 3,
#  'fond de veau': 3,
#  'curry': 3,
#  'poivrons': 3,
#  'piment': 3,
#  'lamproie': 3,
#  'fine Champagne': 3,
#  'couennes de lard porc': 3,
#  'clous girofle': 3,
#  'petit chou': 3,
#  'levure': 3,
#  'graisse de porc': 3,
#  'navet': 3,
#  'gros sel': 3,
#  'raisin': 3,
#  'jarret de porc': 3,
#  'escargots': 3,
#  'noix': 3,
#  'basilic': 3,
#  'pieds de veau': 3,
#  'pointe de piment de Cayenne': 3,
#  'persil haché': 3,
#  'romarin': 3,
#  'coing': 3,
#  'huîtres': 3,
#  'vin Champagne': 3,
#  'piments espagnols': 3,
#  'raisins Malaga': 2,
#  'levure de boulanger': 2,
#  'gelée': 2,
#  'fromage râpé': 2,
#  'marron': 2,
#  'chair à saucisse viande': 2,
#  'côte de bœuf': 2,
#  'chocolat': 2,
#  'thon': 2,
#  'maquereaux': 2,
#  'rougets': 2,
#  'merlans': 2,
#  'haricots secs': 2,
#  'parmesan': 2,
#  "gigot d'agneau": 2,
#  'haricots blancs': 2,
#  'marrons': 2,
#  'eau-de-vie Rhum': 2,
#  'petit oignon': 2,
#  'poivre rouge': 2,
#  'sauge': 2,
#  'cœur céleri': 2,
#  'artichaut': 2,
#  'coulis de tomates': 2,
#  'croûton de pain': 2,
#  "blanc d'œuf": 2,
#  'poularde': 2,
#  'salade': 2,
#  'anguilles': 2,
#  'gras-double bœuf': 2,
#  'vin blanc ou cidre': 2,
#  'cannelle': 2,
#  'glace de viande': 2,
#  'jus de rôti viande': 2,
#  'soles': 2,
#  'cidre': 2,
#  'sauce normande': 2,
#  'zeste orange': 2,
#  'zeste de citron': 2,
#  'entrecôte bœuf': 2,
#  'moelle de bœuf': 2,
#  'échalotes hachées': 2,
#  'mouton': 2,
#  'poireau': 2,
#  'jus de viande': 2,
#  'ciboulettes': 2,
#  'bière': 2,
#  'oronges oiseau': 2,
#  'laitues': 2,
#  'vin jaune': 2,
#  'feuille de vigne': 2,
#  'mirepoix': 2,
#  'jaunes œufs': 2,
#  'saucisson viande': 2,
#  'épaule de porc': 2,
#  'filets morue': 2,
#  'fécule': 2,
#  'champignons de couche': 2,
#  'pointe de Cayenne': 2,
#  'jambon maigre porc': 2,
#  'SAUCE PIQUANTE': 2,
#  'grives oiseau': 2,
#  'foie de volaille': 2,
#  'couenne de porc': 2,
#  'haricots verts': 2,
#  'sauce poivrade': 2,
#  'poitrine porc': 2,
#  'pois frais': 2,
#  'poule': 2,
#  'pruneaux': 2,
#  'carpes': 2,
#  'gibier': 2,
#  'foie viande': 2,
#  'vin Bourgogne': 2,
#  'filet anchois': 2,
#  'sang de poulet': 2,
#  'langouste': 2,
#  'levain': 2,
#  'pâte à brioche': 2,
#  'girofle': 2,
#  'noix de muscade': 2,
#  'grains de raisin': 2,
#  'canapés': 2,
#  'eau-de-vie Mirabelle': 2,
#  'jambon de Bayonne porc': 2,
#  'chorizo': 2,
#  'pointe ail': 2,
#  'piments verts': 2,
#  'quelques amandes': 1,
#  'écorce orange confite': 1,
#  'cannelle en poudre': 1,
#  "eau fleur d'oranger": 1,
#  'choucroute': 1,
#  'pomme': 1,
#  'grains genièvre': 1,
#  'côtes de porc': 1,
#  'saucisses porc': 1,
#  'farine de sarrasin': 1,
#  'petit lait': 1,
#  'pain de seigle': 1,
#  'blanc de poireaux': 1,
#  'champignon': 1,
#  'viande de porc': 1,
#  'viande de veau': 1,
#  'filet de lard porc': 1,
#  'crème ': 1,
#  'laitance carpes': 1,
#  'thon nouveau': 1,
#  'sardines': 1,
#  'coriandre': 1,
#  'filets de morue': 1,
#  'coquilles': 1,
#  'poisson cuit': 1,
#  'chou blanc': 1,
#  'hachis de levraut': 1,
#  'jus de veau': 1,
#  'caneton': 1,
#  'pois nouveaux': 1,
#  'bouquet de sarriette': 1,
#  'farine de blé noir': 1,
#  'couenne de lard porc': 1,
#  'sucre fin': 1,
#  "écorce d'orange ou écorce de citron": 1,
#  'champignons Hygrophores': 1,
#  "beurre d'anchois": 1,
#  'tranches de pain': 1,
#  "gousse d'ail": 1,
#  'Rouille': 1,
#  'bacon porc': 1,
#  "purée d'anchois": 1,
#  'pincée de safran': 1,
#  'pâte à pain': 1,
#  'filets anchois': 1,
#  'poulpes': 1,
#  'poivre rouge doux': 1,
#  'courgettes': 1,
#  'blanc de poireau': 1,
#  'vin Châteauneuf-du-Pape': 1,
#  'filet porc': 1,
#  'cive': 1,
#  'épinard': 1,
#  'bette': 1,
#  'sang de porc': 1,
#  'baudruche de bœuf': 1,
#  'cerises confites': 1,
#  'liqueur Cherry': 1,
#  'pissenlit': 1,
#  'pied de bœuf': 1,
#  'cidre ou vin rouge': 1,
#  'barbue ou turbot': 1,
#  'moules marinière': 1,
#  'canetons': 1,
#  'blanc de poule': 1,
#  'sauce béchamel': 1,
#  'grosses pommes de terre': 1,
#  'haricots verts OU 125 g flageolets': 1,
#  'graisse normande bœuf': 1,
#  'carré de mouton': 1,
#  'oie': 1,
#  'alouettes oiseau': 1,
#  'pommes reinette': 1,
#  'pieds céleri': 1,
#  'pieds de porc truffés': 1,
#  'lait de beurre': 1,
#  'bicarbonate': 1,
#  'salsifis': 1,
#  'grosse raie': 1,
#  "fleurs d'oranger": 1,
#  "zeste d'orange": 1,
#  'cédrat confit': 1,
#  'SAUCE BORDELAISE': 1,
#  'filets de soles': 1,
#  'petits pois écossés': 1,
#  'poitrine de porc': 1,
#  'aromate': 1,
#  'pruneau': 1,
#  'raisin muscat': 1,
#  'gelée de groseille': 1,
#  'cochon': 1,
#  'grain de genièvre': 1,
#  'panais': 1,
#  'saucisse de campagne viande': 1,
#  'filet de lapin': 1,
#  'œufs entiers': 1,
#  'filets harengs': 1,
#  'betteraves': 1,
#  'champignons pied-de-mouton': 1,
#  'vinaigre de cidre': 1,
#  'baies genièvre': 1,
#  'potirons': 1,
#  'petits pains blancs': 1,
#  'pommes reinettes du Canada': 1,
#  'sucre cristallisé': 1,
#  "vin d'Arbois": 1,
#  'rable de lièvre': 1,
#  'bouillon gras': 1,
#  'vin rosé': 1,
#  'gélatine': 1,
#  'mayonnaise': 1,
#  'jarret veau': 1,
#  'poudre champignons': 1,
#  'noisettes': 1,
#  'échalote grise': 1,
#  'grive de vignes oiseau': 1,
#  'fromage Méton': 1,
#  'grenouilles': 1,
#  'fond brun': 1,
#  'merle oiseau': 1,
#  'foie de porc': 1,
#  'panne de porc': 1,
#  'farine blé': 1,
#  'levain salé': 1,
#  'olives dénoyautées': 1,
#  'fromage brocciu': 1,
#  'farine de blé': 1,
#  'farine de châtaigne': 1,
#  'feuilles de châtaignier': 1,
#  'boyau de porc': 1,
#  'poitrine salée porc': 1,
#  "confit d'oie": 1,
#  'saucisses de campagne viande': 1,
#  'couennes porc': 1,
#  'amandes pilées': 1,
#  'feuille laurier': 1,
#  'farine gruau': 1,
#  'sucre ou cassonade': 1,
#  'zeste citron': 1,
#  'sucre glace': 1,
#  'angélique': 1,
#  'échaudé': 1,
#  "hachis d'herbes": 1,
#  'serpolet': 1,
#  'vinaigre blanc': 1,
#  'vin Frontignan': 1,
#  'cresson': 1,
#  'SAUCE BERCY': 1,
#  'jarret veau ou épaule veau': 1,
#  'tomates coupées': 1,
#  'tête de veau': 1,
#  'SAUCE TARTARE': 1,
#  "jaune d'œuf": 1,
#  'volaille ou viande froide': 1,
#  'perche': 1,
#  'SAUCE A LA RAVIGOTE': 1,
#  'côtelettes': 1,
#  'blanc de volaille': 1,
#  'bœuf ou veau': 1,
#  'vinaigrette': 1,
#  'homard': 1,
#  'purée de tomate': 1,
#  'épaule de mouton': 1,
#  'foie gras truffé oiseau': 1,
#  'baies de genièvre': 1,
#  'confiture': 1,
#  'petit pois': 1,
#  'perdrix oiseau': 1,
#  'bouquets garnis': 1,
#  'palette porc': 1,
#  'chou pommé': 1,
#  'raves': 1,
#  'fine Bourgogne': 1,
#  'rumsteack bœuf': 1,
#  'jarrets de veau': 1,
#  'bas morceaux de veau': 1,
#  'gite de bœuf': 1,
#  'vin': 1,
#  'œufs mollets': 1,
#  'vin de Chablis': 1,
#  "grains d'anis": 1,
#  'vin Pouilly': 1,
#  'pigeons oiseau': 1,
#  'foies de volaille': 1,
#  'vin Chambertin': 1,
#  'demi-glace viande': 1,
#  'aromates': 1,
#  'vin Chablis': 1,
#  'grains de poivre': 1,
#  "filet d'anchois": 1,
#  'huile de noix': 1,
#  'saumon': 1,
#  'poitrine veau': 1,
#  'rillons sans os porc': 1,
#  'rillettes porc': 1,
#  'bouillon de bœuf et veau': 1,
#  'jeune caneton': 1,
#  'vin Vouvray': 1,
#  'eau-de-vie marc Touraine ou eau-de-vie Cognac': 1,
#  'farce de porc': 1,
#  'vin de Vouvray': 1,
#  'jeune poule': 1,
#  'citrons': 1,
#  'panne porc': 1,
#  'faisan': 1,
#  'rouge de carottes': 1,
#  'côtelette de chevreuil': 1,
#  'barde de lard salé porc': 1,
#  'alouette oiseau': 1,
#  'jambon fumé porc': 1,
#  'pâte': 1,
#  'pâte à choux': 1,
#  'sauce blanche': 1,
#  'pomme reinette': 1,
#  'pâte brisée': 1,
#  'mie de pain brioché': 1,
#  'maigre de porc': 1,
#  'gras de porc': 1,
#  'eau-de-vie Genièvre': 1,
#  'fond de veau lié': 1,
#  'genièvre': 1,
#  'levreau': 1,
#  'bardes de lard porc': 1,
#  'sang de veau ou sang de porc': 1,
#  'orange': 1,
#  'porc ou lapin ou poulet': 1,
#  'lapin de garenne': 1,
#  'haricots mougettes': 1,
#  'beurre fin': 1,
#  'colin': 1,
#  'crevettes roses': 1,
#  'SAUCE PRIEURE': 1,
#  'petits champignons': 1,
#  'brême': 1,
#  'pois cassés': 1,
#  'fraises des bois': 1,
#  'framboises': 1,
#  'gelée de groseilles': 1,
#  'petit poisson': 1,
#  'goujon': 1,
#  'blancs de poireaux': 1,
#  'crème épaisse': 1,
#  'bardes lard porc': 1,
#  'épinards': 1,
#  'Béchamel': 1,
#  'parmesan râpé': 1,
#  'bananes': 1,
#  'abricots': 1,
#  'grains raisin frais': 1,
#  'loup': 1,
#  'olive noire': 1,
#  'févette': 1,
#  'morue sèche': 1,
#  'chapelure de pain': 1,
#  "têtes d'ail": 1,
#  'foie lapin ou foie poulet': 1,
#  'lard frais porc': 1,
#  'menthe': 1,
#  'petites seiches': 1,
#  'gros poivre': 1,
#  'angélique en poudre': 1,
#  'tomate fraiche OU 1 cuil. tomate concentrée': 1,
#  'gros chou': 1,
#  'os salé viande': 1,
#  'tranches de jambon porc ou boudin noir porc': 1,
#  'anis en grains': 1,
#  'tripes de veau': 1,
#  'clou girofle': 1,
#  'bouillon de poule': 1,
#  'miche de pain': 1,
#  'abatis oie ou canard': 1,
#  'salsifis noirs': 1,
#  'toast': 1,
#  'SAUCE QUERCYNOISE': 1,
#  'jus de rôti de veau': 1,
#  'vin blanc Monbozillac': 1,
#  'glace de viande ou jus de rôti de veau': 1,
#  'eau-de-vie Cognac ou eau-de-vie Armagnac': 1,
#  'vin porto': 1,
#  "graisse de confit d'oie": 1,
#  'farce': 1,
#  'filet de bœuf': 1,
#  'SAUCE PERIGUEUX': 1,
#  'truffe noire': 1,
#  'vin Monbazillac': 1,
#  'épaule et palette porc': 1,
#  'pieds cochon': 1,
#  'cous de mouton': 1,
#  'bouquet de persil': 1,
#  'beurre tiède': 1,
#  'oignon moyen': 1,
#  'gros pain': 1,
#  'sauce mornay': 1,
#  'fromage de Gruyère': 1,
#  'échine porc': 1,
#  'praline': 1,
#  'omble': 1,
#  'duxelle': 1,
#  'chair de brochet': 1,
#  "queues d'écrevisses": 1,
#  "beurre d'écrevisses": 1,
#  'foies poulardes de Bresse': 1,
#  'poulet de Bresse': 1,
#  'piment de Cayenne': 1,
#  'fine ': 1,
#  'petites écrevisses': 1,
#  'lait frais': 1,
#  'vin blanc sec corsé': 1,
#  'alcool Vermouth blanc': 1,
#  'fromage Cantal': 1,
#  'pain bis': 1,
#  'court-bouillon': 1,
#  'vin muscat': 1,
#  'coq': 1,
#  'sucre poudre': 1,
#  'cerises': 1,
#  'œufs battus': 1,
#  'eau-de-vie Rhum ou eau-de-vie Cognac': 1,
#  'essence de citron': 1,
#  'tomates fraîches': 1,
#  'foie de canard': 1,
#  "bouillon d'os": 1,
#  'liqueur Izarra': 1,
#  'farine de maïs': 1,
#  'râpure de citron': 1,
#  'jambon Bayonne porc': 1,
#  "feuilles d'oseille": 1,
#  'feuille de laurier': 1,
#  'vin Jurançon': 1,
#  'ortolans oiseau': 1,
#  'tourterelles oiseau': 1,
#  'jambon des Landes porc': 1,
#  'petits poulets': 1,
#  'lards porc': 1,
#  'pain rassis': 1,
#  'brochets': 1,
#  'vin gris de Bruley': 1,
#  'champignons de Paris': 1,
#  'saucisson porc': 1,
#  'petits pois': 1,
#  'lard maigre porc': 1,
#  'noix de veau': 1,
#  'lard poitrine fumé porc': 1,
#  'congre': 1,
#  'gros grondin': 1,
#  'rascasse': 1,
#  'langoustines': 1,
#  'tête merlu': 1,
#  'piment doux': 1,
#  'tomate concentrée': 1,
#  'riz Caroline': 1,
#  'langoustines crues': 1,
#  'pois': 1,
#  'olives': 1,
#  'palourdes': 1,
#  'piments morones': 1,
#  'palombes': 1,
#  'lard fumé porc': 1,
#  'olives vertes': 1,
#  'tomates fraîches OU 6 cuil. tomate concentrée': 1,
#  'chipirones': 1,
#  'fumet de poissons': 1,
#  'concentré de tomate': 1,
#  'Merluza': 1,
#  "pointes d'asperges": 1,
#  'citron râpé': 1,
#  'crème patissière ou confitures cerises': 1,
#  'escalope de veau': 1,
#  'plates côtes bœuf': 1,
#  'feuilles estragon': 1,
#  'chair à brochet': 1,
#  'jambon haché porc': 1,
#  'cardon': 1,
#  'bouillon de pot au feu': 1,
#  'velouté de volaille': 1,
#  'oronges des Césars oiseau': 1,
#  'paprika doux': 1,
#  'pied mouton': 1,
#  'foie volaille': 1,
#  'harengs marinés': 1,
#  'cervelas truffé': 1}

# %%
set([k for (k, v) in contents_multiset.items() if v > 1])
# Out:
# {'SAUCE PIQUANTE',
#  'ail',
#  'alose',
#  'amandes',
#  'anchois',
#  'anguilles',
#  'artichaut',
#  'aubergines',
#  'barde de lard porc',
#  'basilic',
#  'beurre',
#  'bière',
#  "blanc d'œuf",
#  'bouillon',
#  'bouquet garni',
#  'béchamel',
#  'bœuf',
#  'cailles',
#  'canapés',
#  'canard',
#  'cannelle',
#  'carottes',
#  'carpes',
#  'cerfeuil',
#  'chair à saucisse viande',
#  'champignons',
#  'champignons de couche',
#  'chapelure',
#  'chocolat',
#  'chorizo',
#  'chou',
#  'ciboule',
#  'ciboulette',
#  'ciboulettes',
#  'cidre',
#  'citron',
#  'clou de girofle',
#  'clous de girofle',
#  'clous girofle',
#  'coing',
#  'consommé',
#  'cornichons',
#  'couenne de porc',
#  'couennes de lard porc',
#  'coulis de tomates',
#  'crevettes',
#  'croûton de pain',
#  'croûtons',
#  'croûtons frits',
#  'crème',
#  'crème Chantilly',
#  'crème double',
#  'crème fraîche',
#  'curry',
#  'câpres',
#  'cèpes',
#  'céleri',
#  'côte de bœuf',
#  'cœur céleri',
#  'eau',
#  'eau-de-vie',
#  'eau-de-vie Armagnac',
#  'eau-de-vie Calvados',
#  'eau-de-vie Cognac',
#  'eau-de-vie Kirsch',
#  'eau-de-vie Mirabelle',
#  'eau-de-vie Rhum',
#  'entrecôte bœuf',
#  'escargots',
#  'estragon',
#  'farine',
#  'fenouil',
#  'feuille de vigne',
#  'filet anchois',
#  'filet de porc',
#  'filets morue',
#  'fine Champagne',
#  'fines herbes',
#  "fleur d'oranger",
#  'foie de volaille',
#  'foie gras oiseau',
#  'foie viande',
#  'fond de veau',
#  'fromage râpé',
#  'fécule',
#  'gelée',
#  'gibier',
#  "gigot d'agneau",
#  'girofle',
#  'glace de viande',
#  'grains de raisin',
#  "graisse d'oie",
#  'graisse de porc',
#  'gras-double bœuf',
#  'grives oiseau',
#  'gros oignons',
#  'gros sel',
#  'gruyère',
#  'gruyère râpé',
#  'haricots',
#  'haricots blancs',
#  'haricots secs',
#  'haricots verts',
#  'huile',
#  "huile d'olive",
#  'huile olive',
#  'huîtres',
#  'jambon de Bayonne porc',
#  'jambon maigre porc',
#  'jambon porc',
#  'jarret de porc',
#  "jaunes d'œufs",
#  'jaunes œufs',
#  'jus de citron',
#  'jus de rôti viande',
#  'jus de viande',
#  'lait',
#  'laitue',
#  'laitues',
#  'lamproie',
#  'langouste',
#  'lapin',
#  'lard de poitrine porc',
#  'lard gras porc',
#  'lard porc',
#  'lardons porc',
#  'laurier',
#  'levain',
#  'levure',
#  'levure de boulanger',
#  'lièvre',
#  'lotte',
#  'légumes',
#  'maquereaux',
#  'marron',
#  'marrons',
#  'merlans',
#  'mie de pain',
#  'mirepoix',
#  'moelle de bœuf',
#  'morilles',
#  'moules',
#  'moutarde',
#  'mouton',
#  'muscade',
#  'navet',
#  'navets',
#  'noix',
#  'noix de muscade',
#  'oignons',
#  'olives noires',
#  'oronges oiseau',
#  'oseille',
#  'pain',
#  'paprika',
#  'parmesan',
#  'persil',
#  'persil haché',
#  'petit chou',
#  'petit oignon',
#  'petits oignons',
#  'pied de veau',
#  'pieds de veau',
#  'piment',
#  'piment rouge',
#  'piments espagnols',
#  'piments verts',
#  'pointe ail',
#  'pointe de Cayenne',
#  'pointe de piment de Cayenne',
#  'poireau',
#  'poireaux',
#  'pois frais',
#  'poissons',
#  'poitrine porc',
#  'poivre',
#  'poivre en grains',
#  'poivre rouge',
#  'poivrons',
#  'pomme de terre',
#  'pommes',
#  'pommes de terre',
#  'porc',
#  'poularde',
#  'poule',
#  'poulet',
#  'pruneaux',
#  'pâte feuilletée',
#  'pâte à brioche',
#  'raisin',
#  'raisins Malaga',
#  'riz',
#  'romarin',
#  'rougets',
#  'safran',
#  'saindoux porc',
#  'salade',
#  'sang de poulet',
#  'sarriette',
#  'sauce normande',
#  'sauce poivrade',
#  'sauce tomate',
#  'saucisson viande',
#  'sauge',
#  'sel',
#  'soles',
#  'sucre',
#  'sucre en poudre',
#  'thon',
#  'thym',
#  'tomates',
#  'truffe',
#  'truffes',
#  'truites',
#  'vanille',
#  'veau',
#  'vin Bourgogne',
#  'vin Champagne',
#  'vin Madère',
#  'vin blanc',
#  'vin blanc ou cidre',
#  'vin blanc sec',
#  'vin jaune',
#  'vin rouge',
#  'vinaigre',
#  'vinaigre de vin',
#  'zeste de citron',
#  'zeste orange',
#  'échalote',
#  'échalotes',
#  'échalotes hachées',
#  'écrevisses',
#  'épaule de porc',
#  'épices',
#  'œufs'}

# %%
recipes_df.ingredients[0]
# Out:
# '0.5 litre de lait\n500 g farine\n250 g beurre\n2 œufs\n125 g raisins Malaga\n6 cl eau-de-vie Kirsch\n125 g sucre\n25 g levure de boulanger\n1 pincée de sel\nquelques amandes'

# %%
recipes_analysis = recipes_df.copy()
recipes_analysis['content'] = ''
recipes_analysis['ingredient'] = ''
recipes_analysis['category'] = ''

# %%
for index, row in recipes_analysis.iterrows():
  content = []
  for ingredient in row['ingredients'].split('\n'):
    content.append(create_ingredient_tuple(ingredient))
  row['content'] = content
  row['ingredient'] = [c for (a, b, c) in row.content]
  category = []
  for i in row.ingredient:
    for k in Categories.keys():
      if i in Categories[k]:
        category.append(k)
  row['category'] = category
recipes_analysis
# Out:
#     subregion                                        recipe_name  \
# 0      Alsace                                       LE KUGELHOPF
# 1      Alsace                                   LE SCHWOWCBREDEL
# 2      Alsace               PARFAIT DE FOIE GRAS STRASBOURGEOISE
# 3      Alsace                    TRUITES DE LA FECHT COLMARIENNE
# 4      Alsace                                     LES SCHANKELAS
# ..        ...                                                ...
# 347      Lyon  FEUILLETE AUX ORONGES ET AUX ECREVISSES, MARTELIN
# 348      Lyon                        GRAS-DOUBLE SAUTE LYONNAISE
# 349      Lyon                               LA GALETTE LYONNAISE
# 350      Lyon                               LE SALADIER LYONNAIS
# 351      Lyon                         CERVELAS TRUFFE EN BRIOCHE
#
#     ingredients_inferred nb_persons  \
# 0                   with          6
# 1                   with          6
# 2                   with          -
# 3                   with          4
# 4                   with          -
# ..                   ...        ...
# 347              without          6
# 348                 with          6
# 349                 with        4-5
# 350                 with          4
# 351              without          -
#
#                                            ingredients  \
# 0    0.5 litre de lait\n500 g farine\n250 g beurre\...
# 1    500 g farine\n500 g sucre\n500 g amandes\n500 ...
# 2    1 kg foie gras oiseau\n1 truffe\n1 dl gelée\n1...
# 3    4 truites\n8 écrevisses\n4 œufs\n50 g oignons\...
# 4    375 g sucre\n250 g amandes\n200 g beurre\n250 ...
# ..                                                 ...
# 347  écrevisse\nvin blanc\nlégumes\nvelouté de vola...
# 348  1 kg gras-double bœuf\n2 gros oignons\n6 cl hu...
# 349  10 pommes de terre\n150 g beurre\n3 oignons\ns...
# 350  1 pied mouton\n1 foie volaille\n3 œufs\n2 hare...
# 351               cervelas truffé\npâte à brioche\nœuf
#
#                                            recipe_body  \
# 0    Pour 6 personnes : Mettez dans une terrine 1/2...
# 1    Pour 6 personnes: Mélanger farine et beurre. R...
# 2    1 kg de foie gras d’Alsace 1er qualité, dénerv...
# 3    Pour 4 personnes: Prenez 4 belles truites du t...
# 4    Ecraser le beurre avec la farine et bien mêler...
# ..                                                 ...
# 347  Pour 6 personnes : Faire sauter et cardinalise...
# 348  Pour 6 personnes : Emincer le gras-double en g...
# 349  Pour 4 ou 5 personnes : Préparer une purée de ...
# 350  Pour 4 personnes : Faire une vinaigrette bien ...
# 351  Acheter dans une charcuterie fine un cervelas ...
#
#                                                content  \
# 0    [(0.5, litre, lait), (500, g, farine), (250, g...
# 1    [(500, g, farine), (500, g, sucre), (500, g, a...
# 2    [(1, kg, foie gras oiseau), (1, -, truffe), (1...
# 3    [(4, -, truites), (8, -, écrevisses), (4, -, œ...
# 4    [(375, g, sucre), (250, g, amandes), (200, g, ...
# ..                                                 ...
# 347  [(-, -, écrevisse), (-, -, vin blanc), (-, -, ...
# 348  [(1, kg, gras-double bœuf), (2, -, gros oignon...
# 349  [(10, -, pommes de terre), (150, g, beurre), (...
# 350  [(1, -, pied mouton), (1, -, foie volaille), (...
# 351  [(-, -, cervelas truffé), (-, -, pâte à brioch...
#
#                                             ingredient  \
# 0    [lait, farine, beurre, œufs, raisins Malaga, e...
# 1    [farine, sucre, amandes, beurre, écorce orange...
# 2            [foie gras oiseau, truffe, gelée, beurre]
# 3    [truites, écrevisses, œufs, oignons, vin blanc...
# 4    [sucre, amandes, beurre, farine, œufs, citron,...
# ..                                                 ...
# 347  [écrevisse, vin blanc, légumes, velouté de vol...
# 348  [gras-double bœuf, gros oignons, huile, beurre...
# 349  [pommes de terre, beurre, oignons, sel, poivre...
# 350  [pied mouton, foie volaille, œufs, harengs mar...
# 351             [cervelas truffé, pâte à brioche, œuf]
#
#                                               category
# 0                    [Produit laitier, Céréale, Epice]
# 1                                            [Céréale]
# 2                                         [Champignon]
# 3    [Plante aromatique, Plante aromatique, Plante ...
# 4                            [Céréale, Agrume, Agrume]
# ..                                                 ...
# 347   [Fruit de mer, Légume, Plante aromatique, Epice]
# 348                  [Epice, Epice, Plante aromatique]
# 349                      [Légume, Epice, Epice, Epice]
# 350  [Plante aromatique, Plante aromatique, Plante ...
# 351                                                 []
#
# [352 rows x 9 columns]

# %%
bycat = recipes_analysis.groupby('subregion')['category'].sum().reset_index()
bycat['category_set'] = bycat['category'].apply(lambda x: set(x))
bycat['cat_num'] = bycat['category'].apply(lambda x: len(x))
bycat
# Out:
#         subregion                                           category  \
# 0          Alsace  [Produit laitier, Céréale, Epice, Céréale, Cha...
# 1           Anjou  [Epice, Epice, Epice, Viande, Epice, Epice, Pl...
# 2        Auvergne  [Produit laitier, Produit laitier, Epice, Epic...
# 3       Bordelais  [Céréale, Champignon, Agrume, Epice, Céréale, ...
# 4       Bourgogne  [Plante aromatique, Légume, Epice, Epice, Epic...
# 5          Bresse  [Céréale, Produit laitier, Epice, Epice, Produ...
# 6        Bretagne  [Légume, Agrume, Plante aromatique, Plante aro...
# 7       Champagne  [Plante aromatique, Plante aromatique, Plante ...
# 8       Charentes  [Céréale, Plante aromatique, Agrume, Plante ar...
# 9           Corse  [Epice, Epice, Plante aromatique, Plante aroma...
# 10       Dauphiné  [Céréale, Plante aromatique, Légume, Plante ar...
# 11  Franche-Comté  [Céréale, Epice, Epice, Céréale, Epice, Epice,...
# 12       Gascogne  [Céréale, Produit laitier, Epice, Produit lait...
# 13  Ile-de-France  [Plante aromatique, Epice, Plante aromatique, ...
# 14      Languedoc  [Plante aromatique, Plante aromatique, Plante ...
# 15       Limousin  [Epice, Viande, Légume, Plante aromatique, Pla...
# 16       Lorraine  [Céréale, Viande, Viande, Epice, Plante aromat...
# 17           Lyon  [Céréale, Produit laitier, Epice, Epice, Epice...
# 18           Nice  [Poisson, Légume, Epice, Epice, Légume, Epice,...
# 19           Nord  [Viande, Plante aromatique, Céréale, Viande, V...
# 20      Normandie  [Plante aromatique, Plante aromatique, Plante ...
# 21        Orléans  [Légume, Champignon, Viande, Céréale, Champign...
# 22          Paris  [Epice, Epice, Epice, Plante aromatique, Légum...
# 23    Pays Basque  [Poisson, Poisson, Poisson, Plante aromatique,...
# 24  Poitou Vendée  [Céréale, Plante aromatique, Plante aromatique...
# 25       Provence  [Epice, Epice, Plante aromatique, Plante aroma...
# 26       Périgord  [Epice, Plante aromatique, Plante aromatique, ...
# 27     Roussillon  [Fruit de mer, Plante aromatique, Légume, Plan...
# 28         Savoie  [Produit laitier, Epice, Epice, Légume, Produi...
# 29       Touraine  [Fruit sec, Epice, Epice, Viande, Céréale, Pla...
#
#                                          category_set  cat_num
# 0   {Agrume, Produit laitier, Fruit, Légume, Céréa...       18
# 1   {Agrume, Epice, Produit laitier, Légume, Céréa...       46
# 2   {Produit laitier, Céréale, Champignon, Viande,...       23
# 3   {Agrume, Poisson, Céréale, Champignon, Epice, ...       22
# 4   {Agrume, Produit laitier, Fruit, Alcool, Légum...       53
# 5   {Produit laitier, Légume, Céréale, Champignon,...       39
# 6   {Poisson, Agrume, Produit laitier, Légume, Cér...       88
# 7   {Poisson, Légume, Céréale, Champignon, Viande,...       27
# 8         {Agrume, Céréale, Epice, Plante aromatique}       46
# 9   {Légume, Céréale, Viande, Epice, Plante aromat...       11
# 10  {Produit laitier, Légume, Céréale, Epice, Plan...       15
# 11  {Agrume, Epice, Produit laitier, Fruit, Légume...       51
# 12  {Agrume, Epice, Produit laitier, Légume, Céréa...       15
# 13  {Agrume, Epice, Alcool, Légume, Céréale, Viand...       51
# 14  {Agrume, Produit laitier, Céréale, Fruit sec, ...       18
# 15  {Produit laitier, Légume, Céréale, Champignon,...       39
# 16  {Produit laitier, Légume, Céréale, Champignon,...       43
# 17  {Agrume, Produit laitier, Légume, Fruit de mer...       33
# 18  {Poisson, Légume, Epice, Légumineuse, Plante a...       17
# 19  {Agrume, Produit laitier, Alcool, Légume, Céré...       46
# 20  {Agrume, Produit laitier, Alcool, Légume, Frui...       75
# 21  {Fruit, Légume, Céréale, Champignon, Viande, E...       24
# 22  {Agrume, Poisson, Produit laitier, Légume, Fru...      124
# 23  {Epice, Produit laitier, Légume, Fruit de mer,...       38
# 24  {Epice, Produit laitier, Légume, Céréale, Pois...       33
# 25  {Agrume, Epice, Produit laitier, Légume, Céréa...       60
# 26  {Poisson, Fruit, Légume, Céréale, Fruit sec, C...       42
# 27  {Epice, Fruit, Légume, Fruit de mer, Céréale, ...       34
# 28  {Agrume, Poisson, Produit laitier, Légume, Cér...       33
# 29  {Poisson, Agrume, Céréale, Fruit sec, Viande, ...       32

# %%
bycat.cat_num.plot(kind='hist',
  title='Distribution of number of different categories used by per region',
  xlabel='Number of categories')
# Out:
# <AxesSubplot:title={'center':'Distribution of number of different categories used by per region'}, ylabel='Frequency'>

# %%
bying = recipes_analysis.groupby('subregion')['ingredient'].sum().reset_index()
bying['ingredient_set'] = bying['ingredient'].apply(lambda x: set(x))
bying['ing_num'] = bying['ingredient'].apply(lambda x: len(x))
bying
# Out:
#         subregion                                         ingredient  \
# 0          Alsace  [lait, farine, beurre, œufs, raisins Malaga, e...
# 1           Anjou  [échalotes, beurre, vin blanc, filet porc, lar...
# 2        Auvergne  [truites, beurre, alcool Vermouth blanc, œufs,...
# 3       Bordelais  [farine, levure, œufs, beurre, sucre, fleurs d...
# 4       Bourgogne  [perdrix oiseau, champignons, lard porc, jambo...
# 5          Bresse  [chair de brochet, beurre, œufs, farine, lait,...
# 6        Bretagne  [laitance carpes, thon nouveau, échalote, beur...
# 7       Champagne  [épaule et palette porc, bouillon, vin blanc, ...
# 8       Charentes  [moules, beurre, farine, ail, œuf, citron, per...
# 9           Corse  [merle oiseau, filet de porc, foie de porc, pa...
# 10       Dauphiné  [farine, beurre, œufs battus, levain, eau-de-v...
# 11  Franche-Comté  [morilles, beurre, vin d'Arbois, crème fraîche...
# 12       Gascogne  [foie de canard, vin blanc, tomates, bouillon ...
# 13  Ile-de-France  [anguilles, saindoux porc, oignons, carottes, ...
# 14      Languedoc  [haricots, poitrine salée porc, confit d'oie, ...
# 15       Limousin  [farine de sarrasin, petit lait, sel, porc, lé...
# 16       Lorraine  [petits poulets, lards porc, farine, beurre, c...
# 17           Lyon  [farine, œufs, lait, chair à brochet, beurre, ...
# 18           Nice  [loup, fenouil, huile d'olive, poivre, sel, ch...
# 19           Nord  [lapin, aromate, vinaigre, vin rouge, beurre, ...
# 20      Normandie  [gras-double bœuf, pied de veau, pied de bœuf,...
# 21        Orléans  [pommes de terre, panne porc, carpes, œuf, crè...
# 22          Paris  [beurre, oignon, bouillon, sel, poivre, vinaig...
# 23    Pays Basque  [congre, lotte, gros grondin, rascasse, langou...
# 24  Poitou Vendée  [farine, beurre, œufs, sucre, porc ou lapin ou...
# 25       Provence  [œufs, huile d'olive, mie de pain, sel, poivre...
# 26       Périgord  [bouillon de poule, miche de pain, safran, aba...
# 27     Roussillon  [langouste, beurre, oignons, fine Champagne, v...
# 28         Savoie  [gruyère, eau-de-vie Kirsch, vin blanc, gros p...
# 29       Touraine  [poitrine porc, petit chou, bouillon, pois fra...
#
#                                        ingredient_set  ing_num
# 0   {légumes, crème fraîche, chapelure, pommes de ...       67
# 1   {laitue, lard porc, crème fraîche, lamproie, p...      100
# 2   {fromage Cantal, bouquet garni, lard porc, pou...       55
# 3   {laitue, bouquet garni, lamproie, fleurs d'ora...       75
# 4   {pommes de terre, clous girofle, échalotes, ja...      147
# 5   {crème fraîche, bouquet garni, lait frais, crè...       90
# 6   {vinaigre, bouquet garni, chapelure, lard porc...      172
# 7   {bouquet garni, lard porc, poulet, pied de vea...       66
# 8   {vinaigre, bouquet garni, basilic, gros poivre...      103
# 9   {foie de porc, lard porc, farine de blé, poule...       35
# 10  {œufs battus, bouquet garni, lard porc, pommes...       48
# 11  {crème fraîche, lard porc, vinaigre, chapelure...      107
# 12  {bouillon d'os, crème fraîche, grains de raisi...       61
# 13  {laitue, bouquet garni, lard porc, haricot, vi...      127
# 14  {bouquet garni, jarret de porc, croûtons, jamb...       53
# 15  {légumes, petit lait, pain de seigle, lard por...       83
# 16  {crème fraîche, bouquet garni, lard porc, hari...      102
# 17  {légumes, vinaigre, chapelure, écrevisse, pomm...       71
# 18  {bouquet garni, chapelure, pommes de terre, ol...       31
# 19  {vinaigre, bouquet garni, pommes de terre, rai...      100
# 20  {chapelure, clous girofle, pommes de terre, ja...      179
# 21  {crème fraîche, lard porc, fond de veau lié, c...       81
# 22  {pommes de terre, échalotes, jambon porc, huil...      256
# 23  {concentré de tomate, bouquet garni, chipirone...      118
# 24  {vinaigre, bouquet garni, beurre fin, pied de ...       62
# 25  {crème fraîche, bouquet garni, chapelure, baco...      144
# 26  {bouillon de poule, lard porc, vin porto, pomm...      107
# 27  {vinaigre, bouquet garni, lard porc, gros chou...       76
# 28  {crème fraîche, pommes de terre, poulet, omble...       69
# 29  {vinaigre, bouquet garni, crème fraîche, lampr...       82

# %%
bying.ing_num.plot(kind='hist',
  title='Distribution of number of different ingredients used by per region',
  xlabel='Number of ingredients')
# Out:
# <AxesSubplot:title={'center':'Distribution of number of different ingredients used by per region'}, ylabel='Frequency'>

# %%
bycat
# Out:
#         subregion                                           category  \
# 0          Alsace  [Produit laitier, Céréale, Epice, Céréale, Cha...
# 1           Anjou  [Epice, Epice, Epice, Viande, Epice, Epice, Pl...
# 2        Auvergne  [Produit laitier, Produit laitier, Epice, Epic...
# 3       Bordelais  [Céréale, Champignon, Agrume, Epice, Céréale, ...
# 4       Bourgogne  [Plante aromatique, Légume, Epice, Epice, Epic...
# 5          Bresse  [Céréale, Produit laitier, Epice, Epice, Produ...
# 6        Bretagne  [Légume, Agrume, Plante aromatique, Plante aro...
# 7       Champagne  [Plante aromatique, Plante aromatique, Plante ...
# 8       Charentes  [Céréale, Plante aromatique, Agrume, Plante ar...
# 9           Corse  [Epice, Epice, Plante aromatique, Plante aroma...
# 10       Dauphiné  [Céréale, Plante aromatique, Légume, Plante ar...
# 11  Franche-Comté  [Céréale, Epice, Epice, Céréale, Epice, Epice,...
# 12       Gascogne  [Céréale, Produit laitier, Epice, Produit lait...
# 13  Ile-de-France  [Plante aromatique, Epice, Plante aromatique, ...
# 14      Languedoc  [Plante aromatique, Plante aromatique, Plante ...
# 15       Limousin  [Epice, Viande, Légume, Plante aromatique, Pla...
# 16       Lorraine  [Céréale, Viande, Viande, Epice, Plante aromat...
# 17           Lyon  [Céréale, Produit laitier, Epice, Epice, Epice...
# 18           Nice  [Poisson, Légume, Epice, Epice, Légume, Epice,...
# 19           Nord  [Viande, Plante aromatique, Céréale, Viande, V...
# 20      Normandie  [Plante aromatique, Plante aromatique, Plante ...
# 21        Orléans  [Légume, Champignon, Viande, Céréale, Champign...
# 22          Paris  [Epice, Epice, Epice, Plante aromatique, Légum...
# 23    Pays Basque  [Poisson, Poisson, Poisson, Plante aromatique,...
# 24  Poitou Vendée  [Céréale, Plante aromatique, Plante aromatique...
# 25       Provence  [Epice, Epice, Plante aromatique, Plante aroma...
# 26       Périgord  [Epice, Plante aromatique, Plante aromatique, ...
# 27     Roussillon  [Fruit de mer, Plante aromatique, Légume, Plan...
# 28         Savoie  [Produit laitier, Epice, Epice, Légume, Produi...
# 29       Touraine  [Fruit sec, Epice, Epice, Viande, Céréale, Pla...
#
#                                          category_set  cat_num
# 0   {Agrume, Produit laitier, Fruit, Légume, Céréa...       18
# 1   {Agrume, Epice, Produit laitier, Légume, Céréa...       46
# 2   {Produit laitier, Céréale, Champignon, Viande,...       23
# 3   {Agrume, Poisson, Céréale, Champignon, Epice, ...       22
# 4   {Agrume, Produit laitier, Fruit, Alcool, Légum...       53
# 5   {Produit laitier, Légume, Céréale, Champignon,...       39
# 6   {Poisson, Agrume, Produit laitier, Légume, Cér...       88
# 7   {Poisson, Légume, Céréale, Champignon, Viande,...       27
# 8         {Agrume, Céréale, Epice, Plante aromatique}       46
# 9   {Légume, Céréale, Viande, Epice, Plante aromat...       11
# 10  {Produit laitier, Légume, Céréale, Epice, Plan...       15
# 11  {Agrume, Epice, Produit laitier, Fruit, Légume...       51
# 12  {Agrume, Epice, Produit laitier, Légume, Céréa...       15
# 13  {Agrume, Epice, Alcool, Légume, Céréale, Viand...       51
# 14  {Agrume, Produit laitier, Céréale, Fruit sec, ...       18
# 15  {Produit laitier, Légume, Céréale, Champignon,...       39
# 16  {Produit laitier, Légume, Céréale, Champignon,...       43
# 17  {Agrume, Produit laitier, Légume, Fruit de mer...       33
# 18  {Poisson, Légume, Epice, Légumineuse, Plante a...       17
# 19  {Agrume, Produit laitier, Alcool, Légume, Céré...       46
# 20  {Agrume, Produit laitier, Alcool, Légume, Frui...       75
# 21  {Fruit, Légume, Céréale, Champignon, Viande, E...       24
# 22  {Agrume, Poisson, Produit laitier, Légume, Fru...      124
# 23  {Epice, Produit laitier, Légume, Fruit de mer,...       38
# 24  {Epice, Produit laitier, Légume, Céréale, Pois...       33
# 25  {Agrume, Epice, Produit laitier, Légume, Céréa...       60
# 26  {Poisson, Fruit, Légume, Céréale, Fruit sec, C...       42
# 27  {Epice, Fruit, Légume, Fruit de mer, Céréale, ...       34
# 28  {Agrume, Poisson, Produit laitier, Légume, Cér...       33
# 29  {Poisson, Agrume, Céréale, Fruit sec, Viande, ...       32

# %%
heatmap_df = pd.DataFrame(0, columns=Categories.keys(), index=recipes_df.subregion.unique())
for index, row in recipes_analysis.iterrows():
  new_row = heatmap_df.loc[row.subregion]
  for c in row.category:
    new_row[c] += 1
heatmap_df
# Out:
#                Viande  Poisson  Fruit de mer  Alcool  Plante aromatique  \
# Alsace              0        0             0       0                  3
# Limousin            4        0             0       0                 10
# Bretagne            1        3             0       0                 26
# Provence            0        4             0       0                 27
# Anjou               4        2             0       0                  7
# Normandie           4        0             1       2                 12
# Bordelais           0        1             0       0                  9
# Nord                7        0             0       1                 13
# Franche-Comté       3        2             0       0                  9
# Corse               1        0             0       0                  2
# Languedoc           0        0             0       0                  8
# Paris               5        1             1       0                 50
# Bourgogne           2        0             0       1                 21
# Touraine            2        3             0       0                 15
# Orléans             5        0             0       0                  7
# Poitou Vendée       0        1             0       0                 13
# Ile-de-France       3        2             0       1                 14
# Nice                0        2             0       0                  5
# Charentes           0        0             0       0                 22
# Roussillon          0        2             1       0                 14
# Périgord            4        1             0       0                 13
# Champagne           1        1             0       0                 12
# Savoie              1        1             0       0                  7
# Bresse              0        0             0       0                  6
# Auvergne            2        0             0       0                  5
# Dauphiné            0        0             0       0                  6
# Gascogne            0        2             0       0                  4
# Lorraine            6        0             0       0                 10
# Pays Basque         5        4             1       0                 12
# Lyon                1        0             1       0                  5
#
#                Epice  Produit laitier  Légume  Fruit  Agrume  Céréale  \
# Alsace             2                2       1      1       2        6
# Limousin          15                2       4      0       0        3
# Bretagne          32                8       8      0       5        5
# Provence          16                3       6      0       1        3
# Anjou             21                2       3      0       1        5
# Normandie         30                4       8      0       8        5
# Bordelais          5                0       0      0       2        4
# Nord               9                1       9      0       1        4
# Franche-Comté     25                3       1      1       3        4
# Corse              6                0       1      0       0        1
# Languedoc          4                2       0      0       1        1
# Paris             37                3      17      0       2        8
# Bourgogne         20                2       4      1       1        1
# Touraine           7                0       0      0       1        3
# Orléans            2                0       3      2       0        2
# Poitou Vendée     15                1       1      0       0        2
# Ile-de-France     17                0       4      0       1        6
# Nice               4                0       5      0       0        0
# Charentes         18                0       0      0       2        4
# Roussillon         5                0       4      1       0        7
# Périgord           8                0       3      2       0        5
# Champagne          9                0       2      0       0        1
# Savoie            11                4       5      0       2        1
# Bresse            20                6       1      0       0        4
# Auvergne           7                4       0      0       0        4
# Dauphiné           4                2       2      0       0        1
# Gascogne           1                4       1      0       1        2
# Lorraine          11                4       3      0       0        7
# Pays Basque       10                1       1      0       0        3
# Lyon              14                2       4      0       2        3
#
#                Légumineuse  Fruit sec  Champignon
# Alsace                   0          0           1
# Limousin                 0          0           1
# Bretagne                 0          0           0
# Provence                 0          0           0
# Anjou                    0          0           1
# Normandie                0          0           1
# Bordelais                0          0           1
# Nord                     0          0           1
# Franche-Comté            0          0           0
# Corse                    0          0           0
# Languedoc                0          1           1
# Paris                    0          0           0
# Bourgogne                0          0           0
# Touraine                 0          1           0
# Orléans                  0          0           3
# Poitou Vendée            0          0           0
# Ile-de-France            3          0           0
# Nice                     1          0           0
# Charentes                0          0           0
# Roussillon               0          0           0
# Périgord                 0          1           5
# Champagne                0          0           1
# Savoie                   0          0           1
# Bresse                   0          0           2
# Auvergne                 0          0           1
# Dauphiné                 0          0           0
# Gascogne                 0          0           0
# Lorraine                 0          0           2
# Pays Basque              1          0           0
# Lyon                     0          0           1

# %%
plt.figure(figsize=(10, 15))
# plt.title('Heatmap of categories by region')
sns.heatmap(heatmap_df, cmap="crest", annot=True, fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
coocc = heatmap_df.T.dot(heatmap_df)
np.fill_diagonal(coocc.values, 0)
plt.figure(figsize=(15, 15))
sns.heatmap(coocc, cmap="crest", annot=True, fmt=".8g")
# Out:
# <AxesSubplot:>

# %%
heatmap_df2 = pd.DataFrame(0, columns=Categories.keys(), index=recipes_df.subregion.unique())
for index, row in recipes_analysis.iterrows():
  new_row = heatmap_df2.loc[row.subregion]
  for c in row.category:
    for tup in row.content:
      for k in Categories.keys():
        if tup[2] in Categories[k]:
          if tup[0] == '-':
            new_row[c] += 1
          else:
            new_row[c] += float(tup[0])
heatmap_df2
# Out:
#                Viande  Poisson  Fruit de mer  Alcool  Plante aromatique  \
# Alsace              0        0             0       0                 12
# Limousin           20        0             0       0                 54
# Bretagne            3      857             0       0               1270
# Provence            0     1013             0       0                285
# Anjou              71       70             0       0                198
# Normandie          16        0             6      15                552
# Bordelais           0       26             0       0                 26
# Nord               62        0             0       0                652
# Franche-Comté      19       10             0       0                 58
# Corse               0        0             0       0                  8
# Languedoc           0        0             0       0                 46
# Paris             147        1             7       0                587
# Bourgogne         135        0             0       2               2790
# Touraine            9        4             0       0                570
# Orléans           231        0             0       0                442
# Poitou Vendée       0        6             0       0                574
# Ile-de-France     842        2             0       4                998
# Nice                0       14             0       0                 44
# Charentes           0        0             0       0                167
# Roussillon          0       10             4       0               1199
# Périgord            0        2             0       0               2284
# Champagne           0        4             0       0                 49
# Savoie              0      501             0       0                 37
# Bresse              0        0             0       0                 47
# Auvergne            0        0             0       0                  8
# Dauphiné            0        0             0       0                 14
# Gascogne            0        2             0       0                 20
# Lorraine         1688        0             0       0                845
# Pays Basque       579     3043            37       0               2024
# Lyon                0        0             4       0                 22
#
#                Epice  Produit laitier  Légume  Fruit  Agrume  Céréale  \
# Alsace             4              514     501    501     504     1716
# Limousin          66               15      25      0       0       24
# Bretagne        2031              450     805      0      21      380
# Provence         203                7    1056      0       0     1008
# Anjou            472              183      17      0      65      357
# Normandie        374               15     538      0      34      267
# Bordelais         44                0       0      0      35       81
# Nord             729                1     689      0       6      445
# Franche-Comté    377               21       7      2      21      144
# Corse             56                0       0      0       0       22
# Languedoc         21                9       0      0       7        8
# Paris            394              502     121      0     503     1497
# Bourgogne       2188              332    1000    130       1      325
# Touraine        1033                0       0      0       0      523
# Orléans          205                0       5      4       0       26
# Poitou Vendée    714                7       0      0       0      332
# Ile-de-France   1689                0      23      0       4      123
# Nice              24                0      40      0       0        0
# Charentes        165                0       0      0      24      799
# Roussillon       566                0      24      3       0     1251
# Périgord        2281                0     758      6       0      528
# Champagne         39                0       5      0       0        4
# Savoie          2053              890     302      0     505      511
# Bresse          2669             1171     203      0       0     1004
# Auvergne         273              265       0      0       0       12
# Dauphiné         130              126      13      0       0      500
# Gascogne         511              769       5      0     257      768
# Lorraine        1567              475      37      0       0     1419
# Pays Basque       60                0     502      0       0      829
# Lyon              59                2      20      0       3      155
#
#                Légumineuse  Fruit sec  Champignon
# Alsace                   0          0           1
# Limousin                 0          0           3
# Bretagne                 0          0           0
# Provence                 0          0           0
# Anjou                    0          0           2
# Normandie                0          0           6
# Bordelais                0          0          32
# Nord                     0          0           2
# Franche-Comté            0          0           0
# Corse                    0          0           0
# Languedoc                0          8           6
# Paris                    0          0           0
# Bourgogne                0          0           0
# Touraine                 0          3           0
# Orléans                  0          0          27
# Poitou Vendée            0          0           0
# Ile-de-France           13          0           0
# Nice                     8          0           0
# Charentes                0          0           0
# Roussillon               0          0           0
# Périgord                 0          3         527
# Champagne                0          0           4
# Savoie                   0          0         511
# Bresse                   0          0         203
# Auvergne                 0          0           0
# Dauphiné                 0          0           0
# Gascogne                 0          0           0
# Lorraine                 0          0         264
# Pays Basque             37          0           0
# Lyon                     0          0           0

# %%
plt.figure(figsize=(10, 15))
sns.heatmap(heatmap_df2, cmap="crest", annot=True, fmt=".6g")
# Out:
# <AxesSubplot:>

# %%
coocc2 = heatmap_df2.T.dot(heatmap_df2)
np.fill_diagonal(coocc2.values, 0)
plt.figure(figsize=(15, 15))
sns.heatmap(coocc2, cmap="crest", annot=True, fmt=".8g")
# Out:
# <AxesSubplot:>

# %%
# heatmap_df2['region'] = ''
for idx, row in heatmap_df2.iterrows():
  for (k, v) in Region2SubRegion.items():
    if idx in v:
      row['region'] = k
heatmap_df2
# Out:
#                Viande  Poisson  Fruit de mer  Alcool  Plante aromatique  \
# Alsace              0        0             0       0                 12
# Limousin           20        0             0       0                 54
# Bretagne            3      857             0       0               1270
# Provence            0     1013             0       0                285
# Anjou              71       70             0       0                198
# Normandie          16        0             6      15                552
# Bordelais           0       26             0       0                 26
# Nord               62        0             0       0                652
# Franche-Comté      19       10             0       0                 58
# Corse               0        0             0       0                  8
# Languedoc           0        0             0       0                 46
# Paris             147        1             7       0                587
# Bourgogne         135        0             0       2               2790
# Touraine            9        4             0       0                570
# Orléans           231        0             0       0                442
# Poitou Vendée       0        6             0       0                574
# Ile-de-France     842        2             0       4                998
# Nice                0       14             0       0                 44
# Charentes           0        0             0       0                167
# Roussillon          0       10             4       0               1199
# Périgord            0        2             0       0               2284
# Champagne           0        4             0       0                 49
# Savoie              0      501             0       0                 37
# Bresse              0        0             0       0                 47
# Auvergne            0        0             0       0                  8
# Dauphiné            0        0             0       0                 14
# Gascogne            0        2             0       0                 20
# Lorraine         1688        0             0       0                845
# Pays Basque       579     3043            37       0               2024
# Lyon                0        0             4       0                 22
#
#                Epice  Produit laitier  Légume  Fruit  Agrume  Céréale  \
# Alsace             4              514     501    501     504     1716
# Limousin          66               15      25      0       0       24
# Bretagne        2031              450     805      0      21      380
# Provence         203                7    1056      0       0     1008
# Anjou            472              183      17      0      65      357
# Normandie        374               15     538      0      34      267
# Bordelais         44                0       0      0      35       81
# Nord             729                1     689      0       6      445
# Franche-Comté    377               21       7      2      21      144
# Corse             56                0       0      0       0       22
# Languedoc         21                9       0      0       7        8
# Paris            394              502     121      0     503     1497
# Bourgogne       2188              332    1000    130       1      325
# Touraine        1033                0       0      0       0      523
# Orléans          205                0       5      4       0       26
# Poitou Vendée    714                7       0      0       0      332
# Ile-de-France   1689                0      23      0       4      123
# Nice              24                0      40      0       0        0
# Charentes        165                0       0      0      24      799
# Roussillon       566                0      24      3       0     1251
# Périgord        2281                0     758      6       0      528
# Champagne         39                0       5      0       0        4
# Savoie          2053              890     302      0     505      511
# Bresse          2669             1171     203      0       0     1004
# Auvergne         273              265       0      0       0       12
# Dauphiné         130              126      13      0       0      500
# Gascogne         511              769       5      0     257      768
# Lorraine        1567              475      37      0       0     1419
# Pays Basque       60                0     502      0       0      829
# Lyon              59                2      20      0       3      155
#
#                Légumineuse  Fruit sec  Champignon region
# Alsace                   0          0           1
# Limousin                 0          0           3
# Bretagne                 0          0           0
# Provence                 0          0           0
# Anjou                    0          0           2
# Normandie                0          0           6
# Bordelais                0          0          32
# Nord                     0          0           2
# Franche-Comté            0          0           0
# Corse                    0          0           0
# Languedoc                0          8           6
# Paris                    0          0           0
# Bourgogne                0          0           0
# Touraine                 0          3           0
# Orléans                  0          0          27
# Poitou Vendée            0          0           0
# Ile-de-France           13          0           0
# Nice                     8          0           0
# Charentes                0          0           0
# Roussillon               0          0           0
# Périgord                 0          3         527
# Champagne                0          0           4
# Savoie                   0          0         511
# Bresse                   0          0         203
# Auvergne                 0          0           0
# Dauphiné                 0          0           0
# Gascogne                 0          0           0
# Lorraine                 0          0         264
# Pays Basque             37          0           0
# Lyon                     0          0           0

# %%
heatmap_df2.groupby('region').count()
# Out:
#         Viande  Poisson  Fruit de mer  Alcool  Plante aromatique  Epice  \
# region
#             30       30            30      30                 30     30
#
#         Produit laitier  Légume  Fruit  Agrume  Céréale  Légumineuse  \
# region
#                      30      30     30      30       30           30
#
#         Fruit sec  Champignon
# region
#                30          30
